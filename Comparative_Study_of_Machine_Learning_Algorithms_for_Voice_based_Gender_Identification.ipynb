# %% [markdown]
# # **Enhanced Gender Recognition in Telugu Speech Using Augmented Transgender Audio**

# %% [markdown]
# # Using MFCC + Pitch Features :

# %% [markdown]
# # **Random Forest Classifier**

# %% [markdown]
# **Before Augmentation:**
#
# https://colab.research.google.com/drive/15A0jwdh2L-FtfCUhpwhpIp78npuK4hwc?usp=sharing
#
# **After Augmentation:**
#
# https://colab.research.google.com/drive/10lPPMD6tiWNLfBxgVuekI_CDumg25bI5?usp=sharing

# %% [markdown]
# # **Support Vector Machine (SVM)**

# %% [markdown]
# **Before Augmentaion:**
#
# SVM features extractionM MFCC and Pitch: https://colab.research.google.com/drive/1iw_kZVaJtANh23t63z0HLKWy-pDayl5e?usp=sharing
#
# SVM training and testing:
# https://colab.research.google.com/drive/1YQCs8D6sSbYxcynx_Q8qkDEsgBu1WVdk?usp=sharing
#
# **After Augmentation:**
#
# SVM features extraction MFCC and Pitch:  https://colab.research.google.com/drive/1xBob_3SuoWKMAL31yKdS9SLQfrjsGBe1?usp=sharing
#
# SVM training and testing:https://colab.research.google.com/drive/1ZpBmIUrQWXoZChNFWfFVfqdVWTU2ksIF?usp=sharing

# %% [markdown]
# # **K-Nearest Neighbors (KNN)**

# %% [markdown]
# **Before and After Augmentation:**
#
# https://colab.research.google.com/drive/16pJdPXVzxMsOl1TLNaX8u_uXuX0Q5Ws1?usp=sharing#scrollTo=tq5WkjAqV6U-

# %% [markdown]
# # **Multi-Layer Perceptron (MLP)**

# %% [markdown]
# **Before and After Augmentation:**
#
# https://colab.research.google.com/drive/1OcYEcZUDBBLq70EOofX6neqQ15mW0yqm?usp=sharing

# %% [markdown]
# # **XGBoost Classifier**

# %% [markdown]
# **Before and After Augmentation:**
#
# https://colab.research.google.com/drive/1us0ZRsunySqXo4wvp0eAbkF6YvCWkJiS?usp=sharing

# %% [markdown]
# # Using Wav2Wec2 Features :

# %% [markdown]
# ## XG Boost
# https://colab.research.google.com/drive/1rpI-T1Xha9uws_tb8JLK8SYdf1PhKiS4?usp=sharing

# %% [markdown]
# ## **Support Vector Machine (SVM)**
#
# https://colab.research.google.com/drive/103aPS3T0T-sJ9Rfv9MUB1FDb7JHyWvJl?usp=sharing

# %% [markdown]
# ## **Random Forest Classifier**
# https://colab.research.google.com/drive/1wf4rPXujHZ024pkiUrxpMVSXQiBPgjjJ?usp=sharing

# %% [markdown]
# ## **K-Nearest Neighbors (KNN)**
# https://colab.research.google.com/drive/1q1gfBLwGTZl794OfDi3O4YjvHOlpcW8x?usp=sharing

# %% [markdown]
# ## **Multi-Layer Perceptron (MLP)**
# https://colab.research.google.com/drive/14TAPKDRNSegP9e6vtAPwifLJM5-u1xEp?usp=sharing

# %% [markdown]
# #Telugu Audio Dataset Link
#
# https://drive.google.com/drive/folders/1QOvzKANNn7NdQgcWy2r3bGu8eAOJZxAy?usp=sharing

# %% [markdown]
# # WAv2Wec2 Extracted Features
# https://drive.google.com/drive/folders/1ZOnRHnR6RNFL2mii7MeLHzXnbtHcxTs-?usp=drive_link

# %% [markdown]
# ## MFCC +Pitch extracted features (535 trans)
# https://docs.google.com/spreadsheets/d/1V3ucliy5QP-QDPwDMXawCZda6y6t-9Zr/edit?usp=sharing&ouid=103710721229329094526&rtpof=true&sd=true
